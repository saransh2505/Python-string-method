# %%
string = "this is string methods"

# %% [markdown]
# # string.capitalize()

# %%
string = "this is string methods"
print(string.capitalize())
# Out:
# This is string methods

# %% [markdown]
# # string.casefold()

# %%
string = "This is string methods"
print(string.casefold())
# Out:
# this is string methods

# %% [markdown]
# # string.center()

# %%
string = "hello"
print(string.center(9,"$"))
# Out:
# $$hello$$

# %% [markdown]
# # string.upper()

# %%
string = "python"
print(string.upper())
# Out:
# PYTHON

# %% [markdown]
# # string.count()

# %%
string = "helloooooo"
print(string.count("o"))
print(string.count("o",5,len(string)))
# Out:
# 6
# 5

# %% [markdown]
# # string.encode()

# %%
string = "python"
print(string.encode())
# Out:
# b'python'

# %% [markdown]
# # string.find()

# %%
string = "this is string"
print(string.find("n"))
print(string.find("t" ,7,10))
# Out:
# 12
# 9

# %% [markdown]
# # string.endswith()

# %%
string = "hello python"
print(string.endswith("n"))
print(string.endswith("p"))
# Out:
# True
# False

# %% [markdown]
# # string.lower()

# %%
string = "JAVA"
print(string.lower())
# Out:
# java

# %% [markdown]
# # string.replace()

# %%
string = "hii python"
print(string.replace("hii","Hello"))
# Out:
# Hello python

# %% [markdown]
# # string.zfill()

# %%
string = "hello"
print(string.zfill(7))
# Out:
# 00hello

# %% [markdown]
# # string.expandtabs()

# %%
string = "P\tY\tT\Ht\Ot\tN"
print(string.expandtabs(6))
# Out:
# P     Y     T\Ht\Ot     N

# %% [markdown]
# # string.startswith()

# %%
string = "hello"
print(string.startswith("h"))
print(string.startswith("o"))
# Out:
# True
# False

# %% [markdown]
# # string.isalnum()

# %%
string1 = "hello"
string2 = "125"
string3 = "python55"
string4 = "hello python"
print(string1.isalnum())
print(string2.isalnum())
print(string3.isalnum())
print(string4.isalnum())
# Out:
# True
# True
# True
# False

# %% [markdown]
# # string.index()

# %%
string = "this is python"
print(string.index("is"))
print(string.index("is",4))
# Out:
# 2
# 5

# %% [markdown]
# # string.rindex()

# %%
string = "this is python"
print(string.rindex("is"))
print(string.rindex("is",0,4))
# Out:
# 5
# 2

# %% [markdown]
# # string.isalpha()

# %%
string1 = "hello"
string2 = "123"
print(string1.isalpha())
print(string2.isalpha())
# Out:
# True
# False

# %% [markdown]
# # string.isdigit()

# %%
string1 = "1"
string2 = "a"
print(string1.isdigit())
print(string2.isdigit())
# Out:
# True
# False

# %% [markdown]
# # string.islower()

# %%
string1 = ("java")
string2 = ("PYTHON")
print(string1.islower())
print(string2.islower())
# Out:
# True
# False

# %% [markdown]
# # string.format()

# %%
name = "shivam"
age = 19
string = ("Hi {} your age is {}").format(name,age)
print(string)
# Out:
# Hi shivam your age is 19

# %% [markdown]
# # string.isascii()

# %%
string = "this is python class"
string1 = "125"
string2 = "hello@"
print(string.isascii())
print(string1.isascii())
print(string2.isascii())
# Out:
# True
# True
# True

# %% [markdown]
# # string.isdecimal()

# %%
string = "2525"
string1 = "hello python"
string2 = "2.5"
print(string.isdecimal())
print(string1.isdecimal())
print(string2.isdecimal())
# Out:
# True
# False
# False

# %% [markdown]
# # string.isspace()

# %%
string = "  "
string1 = "hello python"
print(string.isspace())
print(string1.isspace())
# Out:
# True
# False

# %% [markdown]
# # string.istitle()

# %%
string = "Saraansh"
string1 = "saraansh"
print(string.istitle())
print(string1.istitle())
# Out:
# True
# False

# %% [markdown]
# # string.isupper()

# %%
string = "HELLO"
string1 = "hello"
string2 = "Hello"
print(string.isupper())
print(string1.isupper())
print(string2.isupper())
# Out:
# True
# False
# False

# %% [markdown]
# # string.title()

# %%
string = "name"
print(string.title())
# Out:
# Name

# %% [markdown]
# # string.rfind()

# %%
string = "hello hello"
print(string.rfind("l"))
print(string.rfind("o" ,3,7))
# Out:
# 9
# 4

# %% [markdown]
# # string.isprintable()

# %%
string = "python"
string1 = "pyt\nhon"
print(string.isprintable())
print(string1.isprintable())
# Out:
# True
# False

# %% [markdown]
# # string.isidentifier()

# %%
string1 = "abcd"
string2 = "ab cd"
string3 = "52"
string4 = "ab45"
print(string1.isidentifier())
print(string2.isidentifier())
print(string3.isidentifier())
print(string4.isidentifier())
# Out:
# True
# False
# False
# True

# %% [markdown]
# # string.split()

# %%
languages = "python,java,sql"
print(languages.split("java"))
# Out:
# ['python,', ',sql']

# %% [markdown]
# # string.rsplit()

# %%
name = "java,python,sql"
print(name.rsplit(""))
# Out:
# ['java,python,sql']

# %% [markdown]
# # string.swapcase()

# %%
text = "Hello world"
print(text.swapcase())
# Out:
# hELLO WORLD

# %% [markdown]
# # string.strip()

# %%
text = "    abcd"
print(text.strip())
# Out:
# ab cd

# %% [markdown]
# # string.lstrip()

# %%
name = "         shivam           "
print(name.lstrip())
# Out:
# shivam

# %% [markdown]
# # string.rstrip()

# %%
name = "     hello       "
print(name.rstrip())
# Out:
#      hello

# %% [markdown]
# # string.splitlines()

# %%
text = "this is \npython class"
print(text.splitlines())
# Out:
# ['this is ', 'python class']

# %% [markdown]
# # string.join()

# %%
s1 = "python"
s2 = "text"
s3 = "book"
print (" ".join([s1,s2,s3]))
# Out:
# python text book

# %% [markdown]
# # string.partition()

# %%
text = "it is my string"
print(text.partition("my"))
# Out:
# ('it is ', 'my', ' string')

# %% [markdown]
# # string.rpartition()

# %%
text = "this is formatting"
print(text.rpartition("this"))
# Out:
# ('', 'this', ' is formatting')

# %% [markdown]
# # string.removeprefix()

# %%
text = "helloworld"
text1 = "helloworld"
print(text.removeprefix("hello"))
print(text1.removeprefix("world"))
# Out:
# world
# helloworld

# %% [markdown]
# # string.removesuffix()

# %%
text = "pythonjava"
text1 ="pythonjava"
print(text.removesuffix("python"))
print(text1.removesuffix("java"))
# Out:
# pythonjava
# python

# %% [markdown]
# # string.ljust()

# %%
text = "python"
result = text.ljust(5,"$")
print(result)
# Out:
# python

# %% [markdown]
# # string.rjust()

# %%
text = "java"
result = text.rjust(3,"*")
print(result)
# Out:
# java

# %% [markdown]
# # string.formate_map()

# %%
data = {"name":"saraansh","age":20}
text = "My name is {name} and I am {age} year old."
result = text.format_map(data)
print(result)
# Out:
# My name is saraansh and I am 20 year old.
